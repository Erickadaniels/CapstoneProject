# %% [markdown]
# # Lux Academy Captone Project

# %% [markdown]
# ## Data Collection and Preprocessing

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df=pd.read_csv("assignment.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Data Cleaning

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Encoding Categorical Variable

# %%
# Create a copy of the original DataFrame
df_encoded = df.copy()

# Initialize the LabelEncoder
le = LabelEncoder()

le = LabelEncoder()
for column in df.select_dtypes(include=['object']):
    df_encoded[column] = le.fit_transform(df_encoded[column])
df_encoded
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
scaler = StandardScaler()
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
df_encoded[numeric_columns] = scaler.fit_transform(df[numeric_columns])
df_encoded
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0           5375       0      -0.439916        1           0 -1.277445
# 1           3962       1      -0.439916        0           0  0.066327
# 2           2564       1      -0.439916        0           0 -1.236724
# 3           5535       1      -0.439916        0           0  0.514251
# 4           6511       0      -0.439916        0           0 -1.236724
# ...          ...     ...            ...      ...         ...       ...
# 7038        4853       1      -0.439916        1           1 -0.340876
# 7039        1525       0      -0.439916        1           1  1.613701
# 7040        3367       0      -0.439916        1           1 -0.870241
# 7041        5934       1       2.273159        1           0 -1.155283
# 7042        2226       1      -0.439916        0           0  1.369379
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
negative_values = df_encoded[df_encoded < 0]
negative_values
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0            NaN     NaN      -0.439916      NaN         NaN -1.277445
# 1            NaN     NaN      -0.439916      NaN         NaN       NaN
# 2            NaN     NaN      -0.439916      NaN         NaN -1.236724
# 3            NaN     NaN      -0.439916      NaN         NaN       NaN
# 4            NaN     NaN      -0.439916      NaN         NaN -1.236724
# ...          ...     ...            ...      ...         ...       ...
# 7038         NaN     NaN      -0.439916      NaN         NaN -0.340876
# 7039         NaN     NaN      -0.439916      NaN         NaN       NaN
# 7040         NaN     NaN      -0.439916      NaN         NaN -0.870241
# 7041         NaN     NaN            NaN      NaN         NaN -1.155283
# 7042         NaN     NaN      -0.439916      NaN         NaN       NaN
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %% [markdown]
# ## Dropping Negative Values

# %%
df_cleaned = df_encoded[df_encoded >= 0].dropna()
df_cleaned
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 30          2700       0       2.273159        1           0  1.572981
# 50          5686       0       2.273159        0           0  0.432811
# 54          3265       0       2.273159        1           1  1.125057
# 57          3578       1       2.273159        1           1  1.369379
# 72          1272       1       2.273159        1           1  1.287938
# ...          ...     ...            ...      ...         ...       ...
# 6973        7030       0       2.273159        1           0  0.840014
# 6987        4240       0       2.273159        0           0  0.107048
# 6993        4666       0       2.273159        1           0  0.717853
# 7015         453       1       2.273159        1           0  0.066327
# 7023         701       0       2.273159        1           0  1.247218
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %% [markdown]
# ## Scaling Numerical Features

# %%
#scaler = StandardScaler()
#numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
#df[numeric_columns] = scaler.fit_transform(df[numeric_columns])
#df[numeric_columns]

# %% [markdown]
# ## Feature Engineering

# %%
df_clean = df_encoded [df_encoded  >= 0].dropna()
df_clean
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 30          2700       0       2.273159        1           0  1.572981
# 50          5686       0       2.273159        0           0  0.432811
# 54          3265       0       2.273159        1           1  1.125057
# 57          3578       1       2.273159        1           1  1.369379
# 72          1272       1       2.273159        1           1  1.287938
# ...          ...     ...            ...      ...         ...       ...
# 6973        7030       0       2.273159        1           0  0.840014
# 6987        4240       0       2.273159        0           0  0.107048
# 6993        4666       0       2.273159        1           0  0.717853
# 7015         453       1       2.273159        1           0  0.066327
# 7023         701       0       2.273159        1           0  1.247218
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df_encoded['AvgChargesPerMonth'] = df_encoded['TotalCharges'] / df_encoded['tenure']
df_encoded['AvgChargesPerMonth']
# Out:
# 0       -1960.946120
# 1       22102.473159
# 2        -126.948270
# 3        2722.403761
# 4        -747.943628
#             ...
# 7038    -4684.985092
# 7039     3531.012964
# 7040    -3440.426484
# 7041    -2302.465167
# 7042     3948.504958
# Name: AvgChargesPerMonth, Length: 7043, dtype: float64

# %%
service_features = ['TechSupport', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'StreamingTV', 'StreamingMovies']
df_encoded['ServiceInteractions'] = df_encoded[service_features].sum(axis=1)
df_encoded['ServiceInteractions']
# Out:
# 0        2
# 1        4
# 2        4
# 3        6
# 4        0
#         ..
# 7038    10
# 7039     8
# 7040     2
# 7041     0
# 7042    10
# Name: ServiceInteractions, Length: 7043, dtype: int64

# %%
# Example: Creating a new feature 'TotalTransactionValue'
df_encoded['TotalTransactionValue'] = df_cleaned['tenure'] * df_cleaned['MonthlyCharges']

# Display the new feature
df_cleaned[['tenure', 'MonthlyCharges', 'TotalTransactionValue']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[326], line 5
#       2 df_encoded['TotalTransactionValue'] = df_cleaned['tenure'] * df_cleaned['MonthlyCharges']
#       4 # Display the new feature
# ----> 5 df_cleaned[['tenure', 'MonthlyCharges', 'TotalTransactionValue']]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
df_encoded['tenure_with_company'] = df_encoded['tenure']*df_encoded['Contract']
df_encoded['tenure_with_company']

# %% [markdown]
# ## Exploratory Data Analyis

# %% [markdown]
# ### Key factors Contributing to Churn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Countplot of churn distribution
sns.countplot(x='Churn', data=df_encoded)
plt.title('Distribution of Churn')
plt.show()

# Calculate the percentage of churned customers
churn_rate = df['Churn'].value_counts(normalize=True) * 100
print(f"Churn Rate:\n{churn_rate}")
# Out:
# Churn Rate:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
# Histograms for numerical features
numerical_features = ['tenure', 'MonthlyCharges', 'TotalCharges']

for feature in numerical_features:
    plt.figure(figsize=(10, 5))
    sns.histplot(data=df_encoded, x=feature, hue='Churn', kde=True, bins=30)
    plt.title(f'Distribution of {feature} by Churn')
    plt.show()

# %%
# Boxplots for numerical features
for feature in numerical_features:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x='Churn', y=feature, data=df_clean)
    plt.title(f'{feature} vs Churn')
    plt.show()

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df_encoded
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           5375       0              0        1           0       1
# 1           3962       1              0        0           0      34
# 2           2564       1              0        0           0       2
# 3           5535       1              0        0           0      45
# 4           6511       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038        4853       1              0        1           1      24
# 7039        1525       0              0        1           1      72
# 7040        3367       0              0        1           1      11
# 7041        5934       1              1        1           0       4
# 7042        2226       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
service_features = ['TechSupport', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'StreamingTV', 'StreamingMovies']
df_encoded['ServiceInteractions'] = df_encoded[service_features].sum(axis=1)
df_encoded['ServiceInteractions']
# Out:
# 0        2
# 1        4
# 2        4
# 3        6
# 4        0
#         ..
# 7038    10
# 7039     8
# 7040     2
# 7041     0
# 7042    10
# Name: ServiceInteractions, Length: 7043, dtype: int64

# %%
# Correlation matrix
corr = df_encoded.corr()

# Heatmap of correlations
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Countplot of Churn by Contract Type
plt.figure(figsize=(10, 5))
sns.countplot(x='Contract', hue='Churn', data=)
plt.title('Churn by Contract Type')
plt.show()
# Out:
#   Cell In[264], line 3
#     sns.countplot(x='Contract', hue='Churn', data=)
#                                              ^
# SyntaxError: expected argument value expression

# %%
# Create segments for MonthlyCharges
df_cleaned['MonthlyChargesGroup'] = pd.cut(df_cleaned['MonthlyCharges'], bins=[0, 30, 60, 90, 120], 
                                   labels=['Low', 'Medium', 'High', 'Very High'])

# Countplot of Churn by Monthly Charges Group
plt.figure(figsize=(10, 5))
sns.countplot(x='MonthlyChargesGroup', hue='Churn', data=df_cleaned)
plt.title('Churn by Monthly Charges Group')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[267], line 2
#       1 # Create segments for MonthlyCharges
# ----> 2 df_cleaned['MonthlyChargesGroup'] = pd.cut(df_cleaned['MonthlyCharges'], bins=[0, 30, 60, 90, 120],
#       3                                    labels=['Low', 'Medium', 'High', 'Very High'])
#       5 # Countplot of Churn by Monthly Charges Group
#       6 plt.figure(figsize=(10, 5))
#
# NameError: name 'df_cleaned' is not defined

# %%
df_cleaned['tenure_with_company'] = df['tenure']*df['Contract']
df_cleaned['tenure_with_company']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 df_cleaned['tenure_with_company'] = df['tenure']*df['Contract']
#       2 df_cleaned['tenure_with_company']
#
# NameError: name 'df_cleaned' is not defined

# %%
# Create a loyal customer flag based on tenure
df_cleaned['LoyalCustomer'] = df_cleaned['tenure'].apply(lambda x: 1 if x > 36 else 0)
df_cleaned['LoyalCustomer']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[166], line 2
#       1 # Create a loyal customer flag based on tenure
# ----> 2 df_cleaned['LoyalCustomer'] = df_cleaned['tenure'].apply(lambda x: 1 if x > 36 else 0)
#       3 df_cleaned['LoyalCustomer']
#
# NameError: name 'df_cleaned' is not defined

# %%
# Create tenure groups
df_cleaned['TenureGroup'] = pd.cut(df_cleaned['tenure'], bins=[0, 12, 24, 48, 60, 72], labels=['0-1 year', '1-2 years', 
                                                                              '2-4 years', '4-5 years', '5-6 years'])
df_cleaned['TenureGroup']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[168], line 2
#       1 # Create tenure groups
# ----> 2 df_cleaned['TenureGroup'] = pd.cut(df_cleaned['tenure'], bins=[0, 12, 24, 48, 60, 72], labels=['0-1 year', '1-2 years',
#       3                                                                               '2-4 years', '4-5 years', '5-6 years'])
#       4 df_cleaned['TenureGroup']
#
# NameError: name 'df_cleaned' is not defined

# %%
# Create a loyal customer flag based on tenure
df_cleaned['LoyalCustomer'] = df_cleaned['tenure'].apply(lambda x: 1 if x > 36 else 0)
df_cleaned['LoyalCustomer']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[170], line 2
#       1 # Create a loyal customer flag based on tenure
# ----> 2 df_cleaned['LoyalCustomer'] = df_cleaned['tenure'].apply(lambda x: 1 if x > 36 else 0)
#       3 df_cleaned['LoyalCustomer']
#
# NameError: name 'df_cleaned' is not defined
